# %% [markdown]
# ## Validação do dataset

# %% [markdown]
# # Importando Datasets

# %%
import pandas as pd
import os

# --- Configuração ---
dataset_path = r'C:\Github\unicamp-tcc-engenharia-banco-de-dados\Prosposta 01 - Modelo de Machine Learning - Vendas\datasets\Retail Sales Forecasting Data'

# Função auxiliar para carregar um CSV com tratamento de erros
def load_csv_to_df(filename, base_path):
    file_path = os.path.join(base_path, filename)
    try:
        # Tenta com a codificação padrão UTF-8
        return pd.read_csv(file_path, encoding='utf-8', on_bad_lines='skip')
    except UnicodeDecodeError:
        print(f"Aviso: Usando codificação 'latin1' para o arquivo {filename}")
        # Tenta com latin1 se UTF-8 falhar
        return pd.read_csv(file_path, encoding='latin1', on_bad_lines='skip')
    except FileNotFoundError:
        print(f"ERRO: Arquivo não encontrado: {file_path}")
        return None
    except Exception as e:
        print(f"ERRO ao ler {filename}: {e}")
        return None

# --- Carregamento dos Dados em variáveis separadas ---
print("Carregando cada CSV em uma variável de DataFrame dedicada...")

actual_matrix_df = load_csv_to_df('actual_matrix.csv', dataset_path)
catalog_df = load_csv_to_df('catalog.csv', dataset_path)
discounts_history_df = load_csv_to_df('discounts_history.csv', dataset_path)
markdowns_df = load_csv_to_df('markdowns.csv', dataset_path)
online_df = load_csv_to_df('online.csv', dataset_path)
price_history_df = load_csv_to_df('price_history.csv', dataset_path)
sales_df = load_csv_to_df('sales.csv', dataset_path)
stores_df = load_csv_to_df('stores.csv', dataset_path)

print("\n✅ DataFrames carregados!")
# Out:
# Carregando cada CSV em uma variável de DataFrame dedicada...
#
# ✅ DataFrames carregados!

# %% [markdown]
# ### Verificando colunas

# %%
# --- Print do cabeçalho de todos os DataFrames carregados ---
dataframes = [
    ("actual_matrix_df", actual_matrix_df),
    ("catalog_df", catalog_df),
    ("discounts_history_df", discounts_history_df),
    ("markdowns_df", markdowns_df),
    ("online_df", online_df),
    ("price_history_df", price_history_df),
    ("sales_df", sales_df),
    ("stores_df", stores_df)
]

for name, df in dataframes:
    if df is not None:
        print(f"\n--- Cabeçalho do DataFrame '{name}' ---")
        print(df.head())
    else:
        print(f"\n--- DataFrame '{name}' não foi carregado. ---")
# Out:
# --- Cabeçalho do DataFrame 'actual_matrix_df' ---
#    Unnamed: 0       item_id        date  store_id
# 0           0  c578da8e8841  2019-10-17         1
# 1           1  4dd2b686802c  2019-10-17         1
# 2           2  16ade2e3fca9  2019-10-17         1
# 3           3  f4eb16dab09e  2019-10-17         1
# 4           4  ab1384c2af6d  2020-05-31         1
#
# --- Cabeçalho do DataFrame 'catalog_df' ---
#    Unnamed: 0       item_id                 dept_name          class_name  \
# 0           0  da17e2d5feda  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ  БУМАЖНАЯ ПРОДУКЦИЯ
# 1           1  614de2b96018  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ    ВАТНАЯ ПРОДУКЦИЯ
# 2           2  0c1f1f3e3e11  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ    ВАТНАЯ ПРОДУКЦИЯ
# 3           3  71a7fa99f005           ТОВАРЫ ДЛЯ ДОМА              ПОСУДА
# 4           4  ec1bd4d59fe9  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ    ВАТНАЯ ПРОДУКЦИЯ
#
#       subclass_name item_type  weight_volume  weight_netto  fatness
# 0  ВЛАЖНЫЕ САЛФЕТКИ       NaN          150.0           NaN      NaN
# 1      ВАТНЫЕ ДИСКИ       NaN           30.0           NaN      NaN
# 2      ВАТНЫЕ ДИСКИ       NaN            NaN           NaN      NaN
# 3   КУХОННАЯ ПОСУДА       NaN            NaN           NaN      NaN
# 4      ВАТНЫЕ ДИСКИ       NaN           30.0           NaN      NaN
#
# --- Cabeçalho do DataFrame 'discounts_history_df' ---
#    Unnamed: 0        date       item_id  sale_price_before_promo  \
# 0     3648316  2022-08-28  cde97a9ec3ef                    729.9
# 1     3648317  2022-08-28  2906fbc9e11c                    129.9
# 2     3648318  2022-08-28  c48c3a3d8c01                    129.9
# 3     3648319  2022-08-28  f85243ca61e6                    129.9
# 4     3648320  2022-08-28  27ce75534065                    129.9
#
#    sale_price_time_promo  promo_type_code  \
# 0                  669.9              6.0
# 1                   99.9              NaN
# 2                   99.9              NaN
# 3                   99.9              NaN
# 4                   99.9              NaN
#
#                                  doc_id  number_disc_day  store_id
# 0  89ea9f0c-1c08-11ed-ad4d-005056861040             13.0         1
# 1  039e85df-1e51-11ed-ad4d-005056861040             11.0         1
# 2  039e85df-1e51-11ed-ad4d-005056861040             11.0         1
# 3  039e85df-1e51-11ed-ad4d-005056861040             11.0         1
# 4  039e85df-1e51-11ed-ad4d-005056861040             11.0         1
#
# --- Cabeçalho do DataFrame 'markdowns_df' ---
#    Unnamed: 0        date       item_id  normal_price  price  quantity  \
# 0           0  2023-08-01  bc2f82a22e11         189.0  100.0       8.0
# 1           1  2023-08-01  389412076801         179.0  100.0       5.0
# 2           2  2023-08-01  0e39cf5d57c1         149.0  100.0       5.0
# 3           3  2023-08-01  dd94e2bc5601         149.0  100.0       1.0
# 4           4  2023-08-01  e60d890f2812         369.0  270.0       1.0
#
#    store_id
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#
# --- Cabeçalho do DataFrame 'online_df' ---
#    Unnamed: 0        date       item_id  quantity  price_base  sum_total  \
# 0           0  2023-08-04  4aa8dbe05246       3.0       12.40      37.21
# 1           1  2023-08-04  4e0fbcf99cf9       2.0       56.27     112.54
# 2           2  2023-08-04  2e008b673129       2.0       56.27     112.54
# 3           3  2023-08-04  49db9c973903       1.0       29.94      29.94
# 4           4  2023-08-04  9d6072422e8e       1.0       80.10      80.10
#
#    store_id
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#
# --- Cabeçalho do DataFrame 'price_history_df' ---
#    Unnamed: 0        date       item_id  price        code  store_id
# 0           0  2023-08-01  4a1f95fe4d4b  499.9           1         1
# 1           1  2023-08-01  bf43a9d3ae13    0.0  9999999999         1
# 2           2  2023-08-01  0dd8744decce  129.9           1         1
# 3           3  2023-08-01  9b38c7e4dba9  136.0           1         1
# 4           4  2023-08-01  b791e8c9347c    0.0           1         1
#
# --- Cabeçalho do DataFrame 'sales_df' ---
#    Unnamed: 0        date       item_id  quantity  price_base  sum_total  \
# 0           0  2023-08-04  293375605257     1.000       47.86      47.86
# 1           1  2023-08-04  a66fdf2c0ae7     3.000       49.60     148.80
# 2           2  2023-08-04  daa46ef49b7a     0.822      379.00     311.54
# 3           3  2023-08-04  a3b49c1bf758     1.000      129.00     129.00
# 4           4  2023-08-04  ab611c5cef62     7.000       79.90     559.30
#
#    store_id
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#
# --- Cabeçalho do DataFrame 'stores_df' ---
#    Unnamed: 0  store_id division            format   city  area
# 0           0         4     Div1          MaxiEuro  City3  1887
# 1           1         3     Div2  Format-7 express  City2   109
# 2           2         2     Div2          Format-6  City1   210
# 3           3         1     Div1          Format-1  City1  1500

# %%
display(catalog_df)
# Out:
#         Unnamed: 0       item_id                 dept_name  \
# 0                0  da17e2d5feda  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
# 1                1  614de2b96018  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
# 2                2  0c1f1f3e3e11  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
# 3                3  71a7fa99f005           ТОВАРЫ ДЛЯ ДОМА
# 4                4  ec1bd4d59fe9  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
# ...            ...           ...                       ...
# 219805      219806  a8eae2f5974a    СЛАДКИЕ МУЧНЫЕ ИЗДЕЛИЯ
# 219806      219807  54a786e4a589    СЛАДКИЕ МУЧНЫЕ ИЗДЕЛИЯ
# 219807      219808  a96e686cb2ff               ДЕТСКИЙ МИР
# 219808      219809  49cdb76c6eb7               ДЕТСКИЙ МИР
# 219809      219810  ab2737cc44fb  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
#
#                 class_name        subclass_name item_type  weight_volume  \
# 0       БУМАЖНАЯ ПРОДУКЦИЯ     ВЛАЖНЫЕ САЛФЕТКИ       NaN          150.0
# 1         ВАТНАЯ ПРОДУКЦИЯ         ВАТНЫЕ ДИСКИ       NaN           30.0
# 2         ВАТНАЯ ПРОДУКЦИЯ         ВАТНЫЕ ДИСКИ       NaN            NaN
# 3                   ПОСУДА      КУХОННАЯ ПОСУДА       NaN            NaN
# 4         ВАТНАЯ ПРОДУКЦИЯ         ВАТНЫЕ ДИСКИ       NaN           30.0
# ...                    ...                  ...       ...            ...
# 219805             ПЕЧЕНЬЕ   ПЕЧЕНЬЕ ФАСОВАННОЕ       NaN            NaN
# 219806             ПЕЧЕНЬЕ   ПЕЧЕНЬЕ ФАСОВАННОЕ       NaN            NaN
# 219807             ИГРУШКИ  РАЗВИВАЮЩИЕ ИГРУШКИ       NaN            NaN
# 219808             ИГРУШКИ  РАЗВИВАЮЩИЕ ИГРУШКИ       NaN            NaN
# 219809    ВАТНАЯ ПРОДУКЦИЯ       ВАТНЫЕ ПАЛОЧКИ       NaN            NaN
#
#         weight_netto  fatness
# 0                NaN      NaN
# 1                NaN      NaN
# 2                NaN      NaN
# 3                NaN      NaN
# 4                NaN      NaN
# ...              ...      ...
# 219805           NaN      NaN
# 219806           NaN      NaN
# 219807           NaN      NaN
# 219808           NaN      NaN
# 219809           NaN      NaN
#
# [219810 rows x 9 columns]

# %% [markdown]
# ### Traduzindo datasets

# %% [markdown]
# Foi traduzido o dataframe catalog_df;
#
# As colunas 'dept_name', 'class_name', 'subclass_name' estão na linguam Búlgaro.

# %%
from langdetect import detect
from collections import Counter

def detectar_idioma_mais_comum(coluna):
    idiomas = []
    for texto in coluna.dropna().unique():
        try:
            idiomas.append(detect(str(texto)))
        except:
            continue
    contagem = Counter(idiomas)
    idioma_mais_comum = contagem.most_common(1)[0]
    return idioma_mais_comum

# Detectar idioma das 3 colunas
for col in ['dept_name', 'class_name', 'subclass_name']:
    idioma, ocorrencias = detectar_idioma_mais_comum(catalog_df[col])
    print(f"🗂️ Coluna '{col}': idioma predominante = {idioma.upper()} ({ocorrencias} ocorrências)")
# Out:
# 🗂️ Coluna 'dept_name': idioma predominante = BG (87 ocorrências)
# 🗂️ Coluna 'class_name': idioma predominante = BG (280 ocorrências)
# 🗂️ Coluna 'subclass_name': idioma predominante = BG (454 ocorrências)

# %%
display(catalog_df)
# Out:
#         Unnamed: 0       item_id                 dept_name  \
# 0                0  da17e2d5feda  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
# 1                1  614de2b96018  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
# 2                2  0c1f1f3e3e11  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
# 3                3  71a7fa99f005           ТОВАРЫ ДЛЯ ДОМА
# 4                4  ec1bd4d59fe9  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
# ...            ...           ...                       ...
# 219805      219806  a8eae2f5974a    СЛАДКИЕ МУЧНЫЕ ИЗДЕЛИЯ
# 219806      219807  54a786e4a589    СЛАДКИЕ МУЧНЫЕ ИЗДЕЛИЯ
# 219807      219808  a96e686cb2ff               ДЕТСКИЙ МИР
# 219808      219809  49cdb76c6eb7               ДЕТСКИЙ МИР
# 219809      219810  ab2737cc44fb  БУМАЖНО-ВАТНАЯ ПРОДУКЦИЯ
#
#                 class_name        subclass_name item_type  weight_volume  \
# 0       БУМАЖНАЯ ПРОДУКЦИЯ     ВЛАЖНЫЕ САЛФЕТКИ       NaN          150.0
# 1         ВАТНАЯ ПРОДУКЦИЯ         ВАТНЫЕ ДИСКИ       NaN           30.0
# 2         ВАТНАЯ ПРОДУКЦИЯ         ВАТНЫЕ ДИСКИ       NaN            NaN
# 3                   ПОСУДА      КУХОННАЯ ПОСУДА       NaN            NaN
# 4         ВАТНАЯ ПРОДУКЦИЯ         ВАТНЫЕ ДИСКИ       NaN           30.0
# ...                    ...                  ...       ...            ...
# 219805             ПЕЧЕНЬЕ   ПЕЧЕНЬЕ ФАСОВАННОЕ       NaN            NaN
# 219806             ПЕЧЕНЬЕ   ПЕЧЕНЬЕ ФАСОВАННОЕ       NaN            NaN
# 219807             ИГРУШКИ  РАЗВИВАЮЩИЕ ИГРУШКИ       NaN            NaN
# 219808             ИГРУШКИ  РАЗВИВАЮЩИЕ ИГРУШКИ       NaN            NaN
# 219809    ВАТНАЯ ПРОДУКЦИЯ       ВАТНЫЕ ПАЛОЧКИ       NaN            NaN
#
#         weight_netto  fatness
# 0                NaN      NaN
# 1                NaN      NaN
# 2                NaN      NaN
# 3                NaN      NaN
# 4                NaN      NaN
# ...              ...      ...
# 219805           NaN      NaN
# 219806           NaN      NaN
# 219807           NaN      NaN
# 219808           NaN      NaN
# 219809           NaN      NaN
#
# [219810 rows x 9 columns]

# %% [markdown]
# ### Realizando tradução

# %%
import pandas as pd
from deep_translator import GoogleTranslator, MyMemoryTranslator
from langdetect import detect
import time
import requests
import warnings

# Ignora avisos de SSL temporariamente (use com cuidado)
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# Função para detectar idioma
def detect_language(text):
    try:
        if isinstance(text, str) and text.strip():
            return detect(text)
        return None
    except:
        return None

# Função para traduzir texto com fallback
def translate_text(text, source='auto', target='pt'):
    if not isinstance(text, str) or not text.strip():
        return text  # Retorna texto original se não for string válida
    
    # Detecta idioma se source='auto'
    if source == 'auto':
        source = detect_language(text) or 'ru'  # Assume russo como padrão se detecção falhar
    
    try:
        # Tenta Google Translate
        translated = GoogleTranslator(source=source, target=target).translate(text)
        return translated
    except Exception as e:
        print(f"Erro no Google Translate para '{text}': {e}")
        try:
            # Fallback para MyMemoryTranslator
            print(f"Tentando MyMemoryTranslator para '{text}'...")
            translated = MyMemoryTranslator(source=source, target=target).translate(text)
            return translated
        except Exception as e2:
            print(f"Erro no MyMemoryTranslator para '{text}': {e2}")
            return text  # Retorna texto original em caso de erro

# Função para traduzir valores únicos de uma coluna
def translate_column(df, column_name):
    print(f"Traduzindo coluna '{column_name}'...")
    # Obtém valores únicos da coluna
    unique_values = df[column_name].dropna().unique()
    # Cria um dicionário de tradução para valores únicos
    translation_map = {val: translate_text(val, source='auto') for val in unique_values}
    
    # Aplica o mapeamento à coluna
    df[column_name] = df[column_name].map(translation_map).fillna(df[column_name])
    return df

# Verifica se catalog_df foi carregado
if catalog_df is not None:
    print("Iniciando tradução das colunas 'dept_name', 'class_name' e 'subclass_name'...")
    
    # Lista de colunas a traduzir
    columns_to_translate = ['dept_name', 'class_name', 'subclass_name']
    
    # Verifica se as colunas existem no DataFrame
    missing_columns = [col for col in columns_to_translate if col not in catalog_df.columns]
    if missing_columns:
        print(f"ERRO: As seguintes colunas não foram encontradas em catalog_df: {missing_columns}")
    else:
        # Traduz cada coluna
        for column in columns_to_translate:
            catalog_df = translate_column(catalog_df, column)
            # Pausa para evitar sobrecarga na API
            time.sleep(2)
        
        print("\n✅ Tradução concluída!")
        
        # Exibe o cabeçalho do catalog_df após tradução
        print("\n--- Cabeçalho do DataFrame 'catalog_df' após tradução ---")
        print(catalog_df.head())
        
        # Opcional: Salva o DataFrame traduzido
        catalog_df.to_csv(os.path.join(dataset_path, 'catalog_translated.csv'), index=False)
else:
    print("ERRO: catalog_df não foi carregado. Verifique o carregamento do arquivo 'catalog.csv'.")
# Out:
# Iniciando tradução das colunas 'dept_name', 'class_name' e 'subclass_name'...
# Traduzindo coluna 'dept_name'...
# Traduzindo coluna 'class_name'...
# Traduzindo coluna 'subclass_name'...
#
# ✅ Tradução concluída!
#
# --- Cabeçalho do DataFrame 'catalog_df' após tradução ---
#    Unnamed: 0       item_id          dept_name           class_name  \
# 0           0  da17e2d5feda  Produtos de papel              Teimoso
# 1           1  614de2b96018  Produtos de papel  Produtos de algodão
# 2           2  0c1f1f3e3e11  Produtos de papel  Produtos de algodão
# 3           3  71a7fa99f005     Carrega a casa                Prato
# 4           4  ec1bd4d59fe9  Produtos de papel  Produtos de algodão
#
#            subclass_name item_type  weight_volume  weight_netto  fatness
# 0   Guardanapos molhados       NaN          150.0           NaN      NaN
# 1      Discos de algodão       NaN           30.0           NaN      NaN
# 2      Discos de algodão       NaN            NaN           NaN      NaN
# 3  Utensílios de cozinha       NaN            NaN           NaN      NaN
# 4      Discos de algodão       NaN           30.0           NaN      NaN

# %%
display(catalog_df)
# Out:
#         Unnamed: 0       item_id          dept_name           class_name  \
# 0                0  da17e2d5feda  Produtos de papel              Teimoso
# 1                1  614de2b96018  Produtos de papel  Produtos de algodão
# 2                2  0c1f1f3e3e11  Produtos de papel  Produtos de algodão
# 3                3  71a7fa99f005     Carrega a casa                Prato
# 4                4  ec1bd4d59fe9  Produtos de papel  Produtos de algodão
# ...            ...           ...                ...                  ...
# 219805      219806  a8eae2f5974a              Doces              Barriga
# 219806      219807  54a786e4a589              Doces              Barriga
# 219807      219808  a96e686cb2ff    A PAZ DE DECIDI              Jogador
# 219808      219809  49cdb76c6eb7    A PAZ DE DECIDI              Jogador
# 219809      219810  ab2737cc44fb  Produtos de papel  Produtos de algodão
#
#                 subclass_name item_type  weight_volume  weight_netto  fatness
# 0        Guardanapos molhados       NaN          150.0           NaN      NaN
# 1           Discos de algodão       NaN           30.0           NaN      NaN
# 2           Discos de algodão       NaN            NaN           NaN      NaN
# 3       Utensílios de cozinha       NaN            NaN           NaN      NaN
# 4           Discos de algodão       NaN           30.0           NaN      NaN
# ...                       ...       ...            ...           ...      ...
# 219805            Baste jejum       NaN            NaN           NaN      NaN
# 219806            Baste jejum       NaN            NaN           NaN      NaN
# 219807                Jogador       NaN            NaN           NaN      NaN
# 219808                Jogador       NaN            NaN           NaN      NaN
# 219809     Palitos de algodão       NaN            NaN           NaN      NaN
#
# [219810 rows x 9 columns]

# %% [markdown]
# ## Download do dataset traduzido para portugues

# %%
import os

# Define o caminho para salvar o arquivo CSV
output_path = os.path.join(dataset_path, 'catalog_translated_pt_br.csv')

# Salva o DataFrame como CSV
catalog_df.to_csv(output_path, index=False, encoding='utf-8')

print(f"✅ Arquivo salvo com sucesso em: {output_path}")
# Out:
# ✅ Arquivo salvo com sucesso em: C:\Github\unicamp-tcc-engenharia-banco-de-dados\Prosposta 01 - Modelo de Machine Learning - Vendas\datasets\Retail Sales Forecasting Data\catalog_translated_pt_br.csv

# %%
# Função para verificar traduções
def check_translations(df, columns):
    print("\n--- Verificação de Traduções ---")
    for column in columns:
        print(f"\nColuna: {column}")
        # Obtém valores únicos
        unique_values = df[column].dropna().unique()
        # Identifica valores que parecem não estar traduzidos (contêm cirílico)
        cyrillic_values = [val for val in unique_values if isinstance(val, str) and any(ord(c) > 127 for c in val)]
        print(f"Total de valores únicos: {len(unique_values)}")
        print(f"Valores únicos: {unique_values[:10]}")  # Mostra até 10 valores para brevidade
        if cyrillic_values:
            print(f"⚠️ Valores possivelmente não traduzidos (contêm cirílico): {cyrillic_values}")
        else:
            print("✅ Nenhum valor em cirílico detectado (parece tudo traduzido).")

# Colunas a verificar
columns_to_check = ['dept_name', 'class_name', 'subclass_name']

# Executa a verificação
if catalog_df is not None:
    check_translations(catalog_df, columns_to_check)
else:
    print("ERRO: catalog_df não está carregado.")
# Out:
# --- Verificação de Traduções ---
#
# Coluna: dept_name
# Total de valores únicos: 193
# Valores únicos: ['Produtos de papel' 'Carrega a casa' 'Produtos para o harém'
#  'Refrescadores, inseticidas' 'Tigres do Confet'
#  'Chocolad, pasta de chocolate' 'Pão' 'Caviar de peixe rio e mar'
#  'Peixe para cerveja' 'Rybki k pivo (não morda)']
# ⚠️ Valores possivelmente não traduzidos (contêm cirílico): ['Produtos para o harém', 'Pão', 'Rybki k pivo (não morda)', 'Carne, pássaro congelado', 'Bebidas com baixo teor de álcool', 'Crepkie bebidas alcoólicas', 'Carrega ataca pessoalmente o útil', 'Amanhã', 'Dano a produtos lácteos', 'Fala, referência', 'Preservação', 'Café', 'Produtos dabéticos', 'Questão dietética', 'Doçura', 'Ingredientes são padaria', 'Caviar de salmão', 'Pássaros', 'CHÁ', 'Petróleo e margarina', 'Acessórios para fumar', 'Automático', 'Produtos rápidos -feitos', 'ÁGUA', 'Cargas e escritório', 'Catálogo Global', 'Interlocação', 'Lealdade de ação (não extermine)', 'As bagas estão congeladas', 'Canhão', 'Produto marinhoы', 'Informação', 'Produtos Dietíticos', 'Óleo de girassol', 'Pérola', 'Óleo outro', 'Conservação étnica', 'Peixe fresco não use', 'Chá colódico', 'Peixe branco é mar', 'Caviar de peixes de esturjão', 'Cozinha étnica e molhos de macarrão', 'Massas étnicas', 'O peixe está vivo', 'Hambúrgueres', 'Caviar de proteína', 'O queijo está fumado', 'Lanches e algas étnicas', 'Prom folclórico', 'Ingredientes para cozinha étnica', 'A gastronomia de salsicha não se preocupa']
#
# Coluna: class_name
# Total de valores únicos: 583
# Valores únicos: ['Teimoso' 'Produtos de algodão' 'Prato' 'Necessário' 'Guardanapos'
#  'Refrescadores, inseticidas' 'Ladrilhos de chocolate' 'CHOCOLATE'
#  'Pão branco' 'Porcos caviar']
# ⚠️ Valores possivelmente não traduzidos (contêm cirílico): ['Produtos de algodão', 'Necessário', 'Pão branco', 'Lanches de roybat e produto marítimo', 'A falha é silenciosa', 'Delicidades de carne para baixo, úmido, úmido', 'Produtos de pôster e fluxo', 'A falha é brilhante', 'Frutas exóticas', 'O peixe é lento', 'Produtos Infantis Escravo 3-X Verão', 'Doméstico', 'Pós', 'Salmão', 'As conservas são peixes', 'Equipe de Confet (não deslize)', 'Não -colon', 'PURÊ', 'Doces são gelatina', 'Confeitos são chocolate', 'Pérola', 'Sushi são pesados', 'Camarão de vannam', 'Café', 'Não', 'Muitos produtos diabéticos', 'A salsicha é úmida', 'Confetы, chocolad, doçura', 'Técnica', 'Ingredientes são padaria', 'Salmão rosa', 'Armazém', 'Óleo creme', 'Criação', 'Pão', 'Pão nacional', 'Suflê', 'Marmelad, marshmallows, pastilhas, suflê', 'Confete crianças com brincadeira', 'Têxteis', 'Dólares', 'Túnica', 'Automático', 'Varen, geléia, conflito, geléia', 'Cozinhar rápido', 'Coffe é natural', 'Outros tipos de açúcar', 'Batatas fritas não se ligam', 'Extrusão de sal', 'GÁS', 'Mercadorias elétricas', 'Os conjuntos de confet não são chocolate', 'Cintilação', 'Pão de gengibre', 'Tais, suportes, quartéis', 'Proteção corporal', 'Cosméticos desajeitados', 'Entrada atrás do cabelo', 'Mannы', 'Carne de mármore', 'Serviço e aluguel', 'Autoquímica', 'Areia de açúcar', 'Produtos médicos', 'Culinária.', 'UÍSQUE', 'Coquetéis, Apertificadores', 'Catálogo Global', 'Interlocação', 'Lembranças', 'A carne está cozida', 'Bolinhos estão congelados', 'Pologs são enlatados', 'Cacau, solução de chocolad', 'Petróleo EV', 'Terapêutico e derivados', 'O estilo é enlatado', 'O pássaro está congelado', 'O leite é condensado', 'Aéreo', 'Produto marinhoы', 'A pasta é enlatada', 'Mingau de cozinha rápida', 'Frutífero', 'Carrega as refeições', 'Swabs, sovies, serão', '14-23f Times, 8Mart, 9 de setembro, 1º de setembro', 'Marinadы', 'A carne é cordeiro refrigerado', 'Óleo 100%', 'Produtos destacáveis \u200b\u200baté 3 anos', 'Calendários', 'Agentes líquidos', 'Caminhando para cães', 'A carne é carne de porco refrigerada', 'Cápsulas', 'Óleo outro', 'Ferramentas de proteção', 'Maçãs', 'Sopas rápidas -feitas', 'Conservação étnica', 'Salsicha fígado', 'Os cogumelos são frescos', 'Bebê', 'O peixe é fresco', 'Íris', 'Remédio', 'SALMÃO', 'Peixe fígado', 'O presunto é enlatado', 'Caviar é vegetal', 'Acessórios para crianças', 'Molhos à base de tomate', 'Não acabado', 'Confeitos são ilegais', 'Variedade de Páscoa', 'Temperos, marinadas para cozinha étnica', 'A bebida de café', 'Acessórios bancários', 'Pânico', 'Até 0,6L.', 'Moloka de substituição', 'Pássaros', 'É piercing', 'Peixe em geléia', 'À beira -mar', 'Alimentação de aves', 'Caviar de esturjão', 'Arbuza, cabeça', 'Massas étnicas', 'Lanches do salão.', 'Inventário', 'O peixe está fumado', 'Cordão', 'Hambúrgueres', 'Própria produção', 'Fruste de frutas do purê', 'A carne é coelho refrigerado', 'Caramelo, íris, drage', 'Vinagre da cozinha étnica', 'O queijo está fumado', 'Tilápia', 'Cigarros eletrônicos', 'Outros molhos de cozinha étnica', 'Lembrança', 'Tinta de ícone', 'Molhos de cozinha étnica', 'Refrigerante, fermento em pó', 'Campeão', 'Óleo', 'Panning étnico', 'Búfalo', 'Snec étnico', 'Um ouriço do mar', 'Não corte salsichas fervidas', 'Cereais étnicos']
#
# Coluna: subclass_name
# Total de valores únicos: 940
# Valores únicos: ['Guardanapos molhados' 'Discos de algodão' 'Utensílios de cozinha'
#  'Necessário' 'Guardanapos' 'Refrescador' 'Ladrilhos de chocolate'
#  'Chocolad 80-100 grama' 'Pelo fabricante' 'G/b']
# ⚠️ Valores possivelmente não traduzidos (contêm cirílico): ['Discos de algodão', 'Utensílios de cozinha', 'Necessário', 'Café, pratos de chá', 'Clássico', 'Médio para uma entrada de TV', 'Acessórios', 'Frutas exóticas', 'Conservação', 'Médio', 'Salmão', 'Purê de frutas', 'Purê', 'Confeitos estão em jejum de chocolate', 'Pérola', 'Própria produção', 'Bebidas não alcool', 'Substituição', 'PÓ', 'Muitos produtos diabéticos', 'Bebê', 'Ingredientes são padaria', 'Vagão', 'Chá de folha 90-100G.', 'Água. Soki', 'Coquetéis. Freshne', 'Chá em pirâmides', 'Aqui está 0,1L a 0,25L', 'Cookies de própria produção', 'Cognac doméstico até 0,375L', 'Óleo creme', 'Confeitos são chocolate', 'Corrosão', 'Doméstico', 'Os acessórios vão jogar', 'Varen, geléia, conflito, geléia', 'Cozinhar rápido', 'Café em grãos criticados', 'Outros tipos de açúcar', 'Café solto', 'Até 0,75L.', 'Aqui estão 0,75L. Até 3l.', 'Elementos de nutrição', 'Caramelo está embalado', 'Chá 25pack.', 'Até 110 gramas', 'Confeitos estão montados em jejum', 'Até 0,6L.', 'CHÁ', 'Sub -produção', 'Chá de presente', 'Os conjuntos de confet não são chocolate', 'Elementos de decoração', 'Confeitos são casamento de chocolate', 'Inutilizável', 'Proteção corporal', 'O caramelo é pesado', 'Forros diários', 'Sabão líquido', 'Mыlo', 'Lâmpadas', 'Produtos para cuidados com as mãos e unhas', 'Maasnы', 'Médio para loucura', 'Coquetéis de vinho', 'Carne de mármore', 'Criação m/y', 'Cartão -presente', 'Substâncias sintéticas', 'Máscaras', 'Culinária.', 'Coquetéis, Apertificadores', 'Catálogo Global', 'Ensolarado de sua própria produção', 'Lembranças', 'A carne está cozida', 'ÁGUA', 'Pologs são enlatados', 'Cacau, solução de chocolad', 'Géis de chuveiro', 'Bicho de estimação', 'esquimó', 'Patriótico Cooliac de 0,7L', 'Casaco patriótico de 0,375L a 0,5L', 'Escócia', 'O estilo é enlatado', 'Aditivos biológicos', 'O leite é condensado', 'A pasta é enlatada', 'Frutífero', 'Carrega as refeições', 'Óleo de cicap', 'Não tenha os pratos da sala de jantar', '14-23f Times, 8Mart, 9 de setembro, 1º de setembro', 'Quartéis', 'Os biscoitos estão em jejum', 'Pasta pasta, você pode', 'Tampões', 'Marinadы', 'A carne é cordeiro refrigerado', 'AVELÃ', 'Balzami, máscaras de Volos', 'Têxteis', 'Pão', 'Salmão rosa', 'Calendários', 'Até 1L.', 'Escândalo', 'Túnica', 'Armênia', 'Caminhando para cães', 'Anti -séptico', 'Disse o inventário', 'Sopas quentes de sua própria produção', 'Geórgia', 'Doçura', 'Misturas, coquetéis', 'Ácido', 'Óleo outro', 'Poléticos', 'Maçãs', 'Xícaras de salsicha', 'Bebidas de álcool', 'Macarrão', 'Sopas rápidas -feitas', 'Referência.', 'Conservação étnica', 'Compota, marte, ácido', 'Tubarões', 'Equipamento turístico', 'Cosméticos e acessórios de sapatos', 'Íris', 'Amanhã', 'Escritório', 'Acessórios para um tópico', 'Pós', 'Detergentes líquidos', 'Produto de refeições de alimentos soltos', 'O peixe é cortado', 'Serviço e aluguel', 'Balzami, perdidos então britânicos', 'Peixe fígado', 'Importação de champanhe', 'O presunto é enlatado', 'Caviar é vegetal', 'Revistas automáticas e de computador', 'Irmãos', 'Waffles são macios', 'Ações', 'O creme está chicoteado', 'Confetes são presos', 'PLÁSTICO', 'Mais difícil', 'Macaronы', 'Óleos', 'Cassetes, lâmina', 'Confeitos são ilegais', 'Variedade de Páscoa', 'Meio para a saída pelas pernas', 'Temperos, marinadas para cozinha étnica', 'A bebida de café', 'Produtos de algodão', 'Decoração de Páscoa', 'Acessórios para lebre', 'Pânico', 'MAMÃO', 'Para móveis', 'Impossões', 'MAÇÃ', 'Dispositivos médicos', 'Chá 100pack.', 'Moloka de substituição', 'Único -garário', 'Brandy Patriótico de 0,375L a 0,5L', 'É piercing', 'Coquetéis', 'Peixe em geléia', 'À beira -mar', 'Símbolos do ano', 'Alimentação de aves', 'Purê carne, peixe + acompanhamento', 'Cookie de cordão', 'Não comercial', 'Floração', 'ALMOÇO', 'Arbuza, cabeça', 'Literatura instável', 'Produtos macaronnos com adições', 'Marítimo', 'Mingau líquido', 'Os acessórios vão se conectar', 'Lançamento de negócios', 'Co ...

# %% [markdown]
# ## Carregando dados traduzidos

# %%
import os

output_path = os.path.join(dataset_path, 'catalog_translated.csv')
if os.path.exists(output_path):
    print(f"✅ Arquivo 'catalog_translated.csv' encontrado em: {output_path}")
    # Opcional: Exibe as primeiras linhas do arquivo salvo
    saved_df = pd.read_csv(output_path, encoding='utf-8')
    print("\n--- Primeiras linhas do arquivo salvo ---")
    print(saved_df.head())
else:
    print(f"⚠️ Arquivo 'catalog_translated.csv' não encontrado. Tentando salvar novamente...")
    catalog_df.to_csv(output_path, index=False, encoding='utf-8')
    print(f"✅ Arquivo salvo novamente em: {output_path}")
# Out:
# ✅ Arquivo 'catalog_translated.csv' encontrado em: C:\Github\unicamp-tcc-engenharia-banco-de-dados\Prosposta 01 - Modelo de Machine Learning - Vendas\datasets\Retail Sales Forecasting Data\catalog_translated.csv
#
# --- Primeiras linhas do arquivo salvo ---
#    Unnamed: 0       item_id          dept_name           class_name  \
# 0           0  da17e2d5feda  Produtos de papel              Teimoso
# 1           1  614de2b96018  Produtos de papel  Produtos de algodão
# 2           2  0c1f1f3e3e11  Produtos de papel  Produtos de algodão
# 3           3  71a7fa99f005     Carrega a casa                Prato
# 4           4  ec1bd4d59fe9  Produtos de papel  Produtos de algodão
#
#            subclass_name item_type  weight_volume  weight_netto  fatness
# 0   Guardanapos molhados       NaN          150.0           NaN      NaN
# 1      Discos de algodão       NaN           30.0           NaN      NaN
# 2      Discos de algodão       NaN            NaN           NaN      NaN
# 3  Utensílios de cozinha       NaN            NaN           NaN      NaN
# 4      Discos de algodão       NaN           30.0           NaN      NaN

# %% [markdown]
# ## Verificando e Corrigindo as Traduções

# %%
import pandas as pd
import re
import os

# Função para verificar se o texto contém caracteres cirílicos
def has_cyrillic(text):
    if not isinstance(text, str):
        return False
    return bool(re.search(r'[\u0400-\u04FF]', text))

# Mapeamento manual para termos problemáticos e suspeitos
manual_translations = {
    'Produtos para o harém': 'Produtos para casa',
    'Rybki k pivo (não morda)': 'Petiscos de peixe para cerveja',
    'Crepkie bebidas alcoólicas': 'Bebidas alcoólicas fortes',
    'CHÁ': 'Chá',
    'ÁGUA': 'Água',
    'Confetы, chocolad, doçura': 'Doces, chocolate, confeitos',
    'Macaronы': 'Macarrão',
    'Produtos para гарема': 'Produtos para casa',
    'Produto marinhoы': 'Produtos marinhos',
    'Mannы': 'Sêmola',
    'Marinadы': 'Marinadas',
    'Mыlo': 'Sabonete',
    'Maasnы': 'Óleos',
    'Maaso productsы': 'Produtos de óleo',
    'Carrega a casa': 'Produtos para casa',
    'Tigres do Confet': 'Doces de confeito',
    'Chocolad, pasta de chocolate': 'Chocolate, pasta de chocolate',
    'Porcos caviar': 'Caviar de peixe',
    'Refrescadores, inseticidas': 'Repelentes e inseticidas',
    'Ladrilhos de chocolate': 'Tabletes de chocolate',
    'Patnant': 'Produtos especiais',
    'Chocolad 80-100 grama': 'Chocolate 80-100 gramas',
    'Refrescador': 'Repelente',
    'Teimoso': 'Papel higiênico',
    'Necessário': 'Produtos essenciais',
    'Pelo fabricante': 'Por fabricante',
    'G/b': 'Gramas por unidade',
}

# Função para retraduzir valores com cirílico ou incorretos
def retranslate_column(df, column_name):
    print(f"Retraduzindo coluna '{column_name}'...")
    # Identifica valores com cirílico ou no mapeamento manual
    cyrillic_values = df[column_name][df[column_name].apply(lambda x: isinstance(x, str) and (has_cyrillic(x) or x in manual_translations))].unique()
    if len(cyrillic_values) == 0:
        print(f"✅ Nenhum valor com cirílico ou problemático encontrado em '{column_name}'.")
        return df
    
    # Cria mapeamento de retradução
    translation_map = {}
    untranslated_values = []
    suspicious_values = []
    for val in cyrillic_values:
        if val in manual_translations:
            translation_map[val] = manual_translations[val]
        else:
            translation_map[val] = val  # Mantém o valor se não estiver no mapeamento
            if has_cyrillic(val):
                untranslated_values.append(val)
            # Flag valores suspeitos
            if any(keyword in val.lower() for keyword in ['carrega', 'tigres', 'chocolad', 'porcos', 'refrescadores', 'ladrilhos', 'patnant', 'teimoso', 'necessário', 'fabricante', 'g/b']):
                suspicious_values.append(val)
    
    # Aplica o mapeamento
    df[column_name] = df[column_name].map(translation_map).fillna(df[column_name])
    print(f"Valores retraduzidos em '{column_name}': {translation_map}")
    if untranslated_values:
        print(f"⚠️ Valores não traduzidos (ainda com cirílico): {untranslated_values}")
    if suspicious_values:
        print(f"⚠️ Valores potencialmente mal traduzidos (revisar): {suspicious_values}")
    return df

# Colunas a retraduzir
columns_to_retranslate = ['dept_name', 'class_name', 'subclass_name']

# Caminho do dataset
dataset_path = r'C:\Github\unicamp-tcc-engenharia-banco-de-dados\Prosposta 01 - Modelo de Machine Learning - Vendas\datasets\Retail Sales Forecasting Data'

# Verifica se catalog_df está carregado; se não, carrega do CSV
if 'catalog_df' not in globals():
    input_path = os.path.join(dataset_path, 'catalog_translated.csv')
    if os.path.exists(input_path):
        print(f"Carregando catalog_df de: {input_path}")
        catalog_df = pd.read_csv(input_path, encoding='utf-8')
    else:
        print(f"ERRO: Arquivo {input_path} não encontrado.")
        exit()

# Inicia a retradução
print("Iniciando retradução das colunas com valores problemáticos...")

# Retraduz cada coluna
for column in columns_to_retranslate:
    catalog_df = retranslate_column(catalog_df, column)

print("\n✅ Retradução concluída!")

# Exibe o cabeçalho do catalog_df após retradução
print("\n--- Cabeçalho do DataFrame 'catalog_df' após retradução ---")
print(catalog_df.head())

# Verifica novamente valores com cirílico
print("\n--- Verificação Final de Traduções ---")
for column in columns_to_retranslate:
    cyrillic_values = catalog_df[column][catalog_df[column].apply(lambda x: isinstance(x, str) and has_cyrillic(x))].unique()
    print(f"\nColuna: {column}")
    print(f"Valores únicos (amostra): {catalog_df[column].dropna().unique()[:10]}")
    if cyrillic_values.size > 0:
        print(f"⚠️ Valores ainda com cirílico: {cyrillic_values}")
    else:
        print("✅ Nenhum valor com cirílico detectado.")

# Salva o DataFrame retraduzido
output_path = os.path.join(dataset_path, 'catalog_translated_final.csv')
catalog_df.to_csv(output_path, index=False, encoding='utf-8')
print(f"✅ Arquivo retraduzido salvo em: {output_path}")
# Out:
# Iniciando retradução das colunas com valores problemáticos...
# Retraduzindo coluna 'dept_name'...
# ✅ Nenhum valor com cirílico ou problemático encontrado em 'dept_name'.
# Retraduzindo coluna 'class_name'...
# ✅ Nenhum valor com cirílico ou problemático encontrado em 'class_name'.
# Retraduzindo coluna 'subclass_name'...
# ✅ Nenhum valor com cirílico ou problemático encontrado em 'subclass_name'.
#
# ✅ Retradução concluída!
#
# --- Cabeçalho do DataFrame 'catalog_df' após retradução ---
#    Unnamed: 0       item_id           dept_name           class_name  \
# 0           0  da17e2d5feda   Produtos de papel      Papel higiênico
# 1           1  614de2b96018   Produtos de papel  Produtos de algodão
# 2           2  0c1f1f3e3e11   Produtos de papel  Produtos de algodão
# 3           3  71a7fa99f005  Produtos para casa                Prato
# 4           4  ec1bd4d59fe9   Produtos de papel  Produtos de algodão
#
#            subclass_name item_type  weight_volume  weight_netto  fatness
# 0   Guardanapos molhados       NaN          150.0           NaN      NaN
# 1      Discos de algodão       NaN           30.0           NaN      NaN
# 2      Discos de algodão       NaN            NaN           NaN      NaN
# 3  Utensílios de cozinha       NaN            NaN           NaN      NaN
# 4      Discos de algodão       NaN           30.0           NaN      NaN
#
# --- Verificação Final de Traduções ---
#
# Coluna: dept_name
# Valores únicos (amostra): ['Produtos de papel' 'Produtos para casa' 'Repelentes e inseticidas'
#  'Doces de confeito' 'Chocolate, pasta de chocolate' 'Pão'
#  'Caviar de peixe rio e mar' 'Peixe para cerveja'
#  'Petiscos de peixe para cerveja' 'Produtos patenteados']
# ✅ Nenhum valor com cirílico detectado.
#
# Coluna: class_name
# Valores únicos (amostra): ['Papel higiênico' 'Produtos de algodão' 'Prato' 'Produtos essenciais'
#  'Guardanapos' 'Repelentes e inseticidas' 'Tabletes de chocolate'
#  'CHOCOLATE' 'Pão branco' 'Caviar de peixe']
# ✅ Nenhum valor com cirílico detectado.
#
# Coluna: subclass_name
# Valores únicos (amostra): ['Guardanapos molhados' 'Discos de algodão' 'Utensílios de cozinha'
#  'Produtos essenciais' 'Guardanapos' 'Repelente' 'Tabletes de chocolate'
#  'Chocolate 80-100 gramas' 'Por fabricante' 'Gramas por unidade']
# ✅ Nenhum valor com cirílico detectado.
# ✅ Arquivo retraduzido salvo em: C:\Github\unicamp-tcc-engenharia-banco-de-dados\Prosposta 01 - Modelo de Machine Learning - Vendas\datasets\Retail Sales Forecasting Data\catalog_translated_final.csv
